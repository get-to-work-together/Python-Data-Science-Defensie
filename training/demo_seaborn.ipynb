# %% [markdown]
# # Demo seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="white")

# Load the example mpg dataset
mpg = sns.load_dataset("mpg")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",
            sizes=(20, 800), alpha=.5, palette="muted",
            height=6, data=mpg)

plt.grid()
plt.title('horsepower vs mpg')
plt.show()

# %%
sns.pairplot(mpg, hue='origin', size="weight", sizes=(40, 400));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.pairplot(mpg, hue='origin', size="weight", sizes=(40, 400));
#
# TypeError: pairplot() got an unexpected keyword argument 'sizes'. Did you mean 'size'?
